# %%
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import time

# %%
# names_columns = ["Testes", "DataHora", "CpuPercent", "QntCpus", "CpuTimesUser", "CpuTimesSystem", "CpuTimesIdle", "MemTotal", "MemAvaliable", "MemUsed", "DiskUsed", "DiskTotal", "DiskPercent", "BytesSend", "BytesRecv"]
# df = pd.read_csv("monitoramento.txt", names=names_columns)

# %%
lines = []
for line in open('/home/laisy/Documentos/ADS/ADS-Scripts/resultado_processo_cpu.txt', 'r'):
    lines.append(line.split())

# %%
print(lines)
# Out:
# [['DATA_ATUAL', 'HORA_ATUAL', 'PID', 'MEMTOTAL', '%CPU', '%MEM', 'TIME', 'MSECOND'], ['2023-03-27', '23:03:49', '26543', '3892952', '6.0', '0.3', '00:00:00', '21600000'], ['2023-03-27', '23:03:50', '26543', '3892952', '3.0', '0.3', '00:00:00', '10800000'], ['2023-03-27', '23:03:51', '26543', '3892952', '2.0', '0.3', '00:00:00', '7200000'], ['2023-03-27', '23:03:52', '26543', '3892952', '1.5', '0.3', '00:00:00', '5400000'], ['2023-03-27', '23:03:53', '26543', '3892952', '1.2', '0.3', '00:00:00', '4320000'], ['2023-03-27', '23:03:54', '26543', '3892952', '1.0', '0.3', '00:00:00', '3600000'], ['2023-03-27', '23:03:55', '26543', '3892952', '0.7', '0.3', '00:00:00', '2520000'], ['2023-03-27', '23:03:56', '26543', '3892952', '0.6', '0.3', '00:00:00', '2160000'], ['2023-03-27', '23:03:57', '26543', '3892952', '0.6', '0.3', '00:00:00', '2160000'], ['2023-03-27', '23:03:58', '26543', '3892952', '0.6', '0.3', '00:00:00', '2160000'], ['2023-03-27', '23:03:59', '26543', '3892952', '0.5', '0.3', '00:00:00', '1800000'], ['2023-03-27', '23:04:00', '26543', '3892952', '0.5', '0.3', '00:00:00', '1800000'], ['2023-03-27', '23:04:01', '26543', '3892952', '0.5', '0.3', '00:00:00', '1800000'], ['2023-03-27', '23:04:02', '26543', '3892952', '0.4', '0.3', '00:00:00', '1440000'], ['2023-03-27', '23:04:03', '26543', '3892952', '0.4', '0.3', '00:00:00', '1440000'], ['2023-03-27', '23:04:04', '26543', '3892952', '0.4', '0.3', '00:00:00', '1440000'], ['2023-03-27', '23:04:05', '26543', '3892952', '0.3', '0.3', '00:00:00', '1080000'], ['2023-03-27', '23:04:07', '26543', '3892952', '0.4', '0.3', '00:00:00', '1440000'], ['2023-03-27', '23:04:08', '26543', '3892952', '0.4', '0.3', '00:00:00', '1440000'], ['2023-03-27', '23:04:09', '26543', '3892952', '0.3', '0.3', '00:00:00', '1080000'], ['2023-03-27', '23:04:10', '26543', '3892952', '0.3', '0.3', '00:00:00', '1080000'], ['2023-03-27', '23:04:11', '26543', '3892952', '0.3', '0.3', '00:00:00', '1080000'], ['2023-03-27', '23:04:12', '26543', '3892952', '0.3', '0.3', '00:00:00', '1080000'], ['2023-03-27', '23:04:13', '26543', '3892952', '0.3', '0.3', '00:00:00', '1080000'], ['2023-03-27', '23:04:14', '26543', '3892952', '0.3', '0.3', '00:00:00', '1080000'], ['2023-03-27', '23:04:15', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:16', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:17', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:18', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:19', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:20', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:21', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:22', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:23', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:24', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:25', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:26', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:27', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:29', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:30', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:31', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:32', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:33', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:34', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:35', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:36', '26543', '3892952', '0.2', '0.3', '00:00:00', '720000'], ['2023-03-27', '23:04:37 ...

# %%
lines.pop(0)
# Out:
# ['DATA_ATUAL',
#  'HORA_ATUAL',
#  'PID',
#  'MEMTOTAL',
#  '%CPU',
#  '%MEM',
#  'TIME',
#  'MSECOND']

# %%
tempos = []
for k in lines:
    date = k[0] + ' ' + k[1]
    date = datetime.strptime(date, '%Y-%m-%d %H:%M:%S')
    hora = date.time()

    tempos.append(date)
 
tempo_processo = tempos[-1] - tempos[0]
print('TEMPO PROCESSO PYTHON COM CARGA:', tempo_processo)
# Out:
# TEMPO PROCESSO PYTHON COM CARGA: 0:04:56

# %%
cpus = []
for k in lines:
    cpus.append(float(k[4]))
 
cpus_utilizada =  "{:.2f}".format(sum(cpus) / len(cpus))
print('%CPU PROCESSO PYTHON COM CARGA:', cpus_utilizada, "%")
# Out:
# %CPU PROCESSO PYTHON COM CARGA: 0.18 %

# %%
memorias = []
for k in lines:
    memorias.append(float(k[5]))
 
memorias_utilizada =  "{:.2f}".format(sum(memorias) / len(memorias))
print('%MEM PROCESSO PYTHON COM CARGA:', memorias_utilizada, "%")
# Out:
# %MEM PROCESSO PYTHON COM CARGA: 0.30 %

# %%
memorias = []
for k in lines:

    # MEMTOTAL bytes
    mem_value = (float(k[5])*int(k[3]))/100
    memorias.append(mem_value)
 
memorias_utilizada = sum(memorias) / len(memorias)
memorias_utilizada = "{:.2f}".format(memorias_utilizada/1024)

print('MEM PROCESSO PYTHON COM CARGA:', memorias_utilizada, 'KB')
# Out:
# MEM PROCESSO PYTHON COM CARGA: 11.41 KB
