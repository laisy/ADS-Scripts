# %%
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import time

# %%
# names_columns = ["Testes", "DataHora", "CpuPercent", "QntCpus", "CpuTimesUser", "CpuTimesSystem", "CpuTimesIdle", "MemTotal", "MemAvaliable", "MemUsed", "DiskUsed", "DiskTotal", "DiskPercent", "BytesSend", "BytesRecv"]
# df = pd.read_csv("monitoramento.txt", names=names_columns)

# %%
lines = []
for line in open('/home/laisy/Documentos/ADS/ADS-Scripts/resultado_processo_bash_cpu.txt', 'r'):
    lines.append(line.split())

# %%
print(lines)
# Out:
# [['DATA_ATUAL', 'HORA_ATUAL', 'PID', 'MEMTOTAL', '%CPU', '%MEM', 'TIME', 'MSECOND'], ['2023-03-29', '02:29:33', '97214', '3892952', '0.3', '0.1', '00:00:00', '1080000'], ['2023-03-29', '02:29:34', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:35', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:36', '97214', '3892952', '0.1', '0.1', '00:00:00', '360000'], ['2023-03-29', '02:29:37', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:38', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:39', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:40', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:41', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:42', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:43', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:44', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:45', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:46', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:48', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:49', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:50', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:51', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:52', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:53', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:54', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:55', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:57', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:58', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:29:59', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:00', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:01', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:03', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:04', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:05', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:06', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:07', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:08', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:10', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:11', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:12', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:13', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:14', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:16', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:17', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:18', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:19', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:20', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:22', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:23', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:24', '97214', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:30:25', '97214', '3892952', '0. ...

# %%
lines.pop(0)
# Out:
# ['DATA_ATUAL',
#  'HORA_ATUAL',
#  'PID',
#  'MEMTOTAL',
#  '%CPU',
#  '%MEM',
#  'TIME',
#  'MSECOND']

# %%
tempos = []
for k in lines:
    date = k[0] + ' ' + k[1]
    date = datetime.strptime(date, '%Y-%m-%d %H:%M:%S')
    hora = date.time()

    tempos.append(date)
 
tempo_processo = tempos[-1] - tempos[0]
print('TEMPO PROCESSO PYTHON COM CARGA:', tempo_processo)
# Out:
# TEMPO PROCESSO PYTHON COM CARGA: 0:05:30

# %%
cpus = []
for k in lines:
    cpus.append(float(k[4]))
 
cpus_utilizada =  "{:.2f}".format(sum(cpus) / len(cpus))
print('%CPU PROCESSO PYTHON COM CARGA:', cpus_utilizada, "%")
# Out:
# %CPU PROCESSO PYTHON COM CARGA: 0.20 %

# %%
memorias = []
for k in lines:
    memorias.append(float(k[5]))
 
memorias_utilizada =  "{:.2f}".format(sum(memorias) / len(memorias))
print('%MEM PROCESSO PYTHON COM CARGA:', memorias_utilizada, "%")
# Out:
# %MEM PROCESSO PYTHON COM CARGA: 0.10 %

# %%
memorias = []
for k in lines:

    # MEMTOTAL bytes
    mem_value = (float(k[5])*int(k[3]))/100
    memorias.append(mem_value)
 
memorias_utilizada = sum(memorias) / len(memorias)
memorias_utilizada = "{:.2f}".format(memorias_utilizada/1024)

print('MEM PROCESSO PYTHON COM CARGA:', memorias_utilizada, 'KB')
# Out:
# MEM PROCESSO PYTHON COM CARGA: 3.80 KB
