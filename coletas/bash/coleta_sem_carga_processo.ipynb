# %%
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import time

# %%
# names_columns = ["Testes", "DataHora", "CpuPercent", "QntCpus", "CpuTimesUser", "CpuTimesSystem", "CpuTimesIdle", "MemTotal", "MemAvaliable", "MemUsed", "DiskUsed", "DiskTotal", "DiskPercent", "BytesSend", "BytesRecv"]
# df = pd.read_csv("monitoramento.txt", names=names_columns)

# %%
lines = []
for line in open('/home/laisy/Documentos/ADS/ADS-Scripts/resultado_processo_bash.txt', 'r'):
    lines.append(line.split())

# %%
print(lines)
# Out:
# [['DATA_ATUAL', 'HORA_ATUAL', 'PID', 'MEMTOTAL', '%CPU', '%MEM', 'TIME', 'MSECOND'], ['2023-03-29', '02:20:56', '87615', '3892952', '0.5', '0.1', '00:00:00', '1800000'], ['2023-03-29', '02:20:57', '87615', '3892952', '0.3', '0.1', '00:00:00', '1080000'], ['2023-03-29', '02:20:59', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:00', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:01', '87615', '3892952', '0.1', '0.1', '00:00:00', '360000'], ['2023-03-29', '02:21:02', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:03', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:04', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:05', '87615', '3892952', '0.3', '0.1', '00:00:00', '1080000'], ['2023-03-29', '02:21:06', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:07', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:08', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:09', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:10', '87615', '3892952', '0.1', '0.1', '00:00:00', '360000'], ['2023-03-29', '02:21:11', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:12', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:13', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:14', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:15', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:16', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:17', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:18', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:20', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:21', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:22', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:23', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:24', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:25', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:26', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:27', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:28', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:29', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:30', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:31', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:32', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:33', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:34', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:35', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:36', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:37', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:38', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:40', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:41', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:42', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:43', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:44', '87615', '3892952', '0.2', '0.1', '00:00:00', '720000'], ['2023-03-29', '02:21:45', '87615', '3892952', ' ...

# %%
lines.pop(0)
# Out:
# ['DATA_ATUAL',
#  'HORA_ATUAL',
#  'PID',
#  'MEMTOTAL',
#  '%CPU',
#  '%MEM',
#  'TIME',
#  'MSECOND']

# %%
tempos = []
for k in lines:
    date = k[0] + ' ' + k[1]
    date = datetime.strptime(date, '%Y-%m-%d %H:%M:%S')
    hora = date.time()

    tempos.append(date)
 
tempo_processo = tempos[-1] - tempos[0]
print('TEMPO PROCESSO PYTHON SEM CARGA:', tempo_processo)
# Out:
# TEMPO PROCESSO PYTHON SEM CARGA: 0:05:08

# %%
cpus = []
for k in lines:
    cpus.append(float(k[4]))
 
cpus_utilizada =  "{:.2f}".format(sum(cpus) / len(cpus))
print('%CPU PROCESSO PYTHON COM CARGA:', cpus_utilizada, "%")
# Out:
# %CPU PROCESSO PYTHON COM CARGA: 0.20 %

# %%
memorias = []
for k in lines:
    memorias.append(float(k[5]))
 
memorias_utilizada =  "{:.2f}".format(sum(memorias) / len(memorias))
print('%MEM PROCESSO PYTHON COM CARGA:', memorias_utilizada, "%")
# Out:
# %MEM PROCESSO PYTHON COM CARGA: 0.10 %

# %%
memorias = []
for k in lines:

    # MEMTOTAL bytes
    mem_value = (float(k[5])*int(k[3]))/100
    memorias.append(mem_value)
 
memorias_utilizada = sum(memorias) / len(memorias)
memorias_utilizada = "{:.2f}".format(memorias_utilizada/1024)

print('MEM PROCESSO PYTHON COM CARGA:', memorias_utilizada, 'KB')
# Out:
# MEM PROCESSO PYTHON COM CARGA: 3.80 KB
