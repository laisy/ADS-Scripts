# %%
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import time

# %%
# names_columns = ["Testes", "DataHora", "CpuPercent", "QntCpus", "CpuTimesUser", "CpuTimesSystem", "CpuTimesIdle", "MemTotal", "MemAvaliable", "MemUsed", "DiskUsed", "DiskTotal", "DiskPercent", "BytesSend", "BytesRecv"]
# df = pd.read_csv("monitoramento.txt", names=names_columns)

# %%
lines = []
for line in open('/home/laisy/Documentos/ADS/ADS-Scripts/Scripts_Bash/monitoramento_bash_memoria.txt', 'r'):
    lines.append(line.split())

# %%
print(lines)
# Out:
# [['Testes', 'Data', 'Hora', 'CpuPercent', 'QntCpus', 'CpuTimesUser', 'CpuTimesSystem', 'CpuTimesIdle', 'MemTotal', 'MemAvaliable', 'MemUsed', 'DiskUsed', 'DiskTotal', 'DiskPercent', 'BytesSend', 'BytesRecv'], ['1', '2023/03/29', '02:41:15', '7.66', '4', '0.02', '2.27', '88.59', '3801', '658', '1784', '72690352', '31837', '479592104', '98304', '0', '0'], ['2', '2023/03/29', '02:41:19', '7.66', '4', '0.02', '2.27', '88.59', '3801', '653', '1784', '72690356', '31837', '479592104', '98304', '0', '0'], ['3', '2023/03/29', '02:41:22', '7.66', '4', '0.02', '2.27', '88.59', '3801', '647', '1782', '72690356', '31837', '479592104', '98304', '0', '0'], ['4', '2023/03/29', '02:41:25', '7.67', '4', '0.02', '2.27', '88.58', '3801', '642', '1789', '72690360', '31837', '479592104', '98304', '0', '0'], ['5', '2023/03/29', '02:41:28', '7.68', '4', '0.02', '2.27', '88.57', '3801', '649', '1787', '72690360', '31837', '479592104', '98304', '0', '0'], ['6', '2023/03/29', '02:41:32', '7.70', '4', '0.02', '
# ...

# %%
lines.pop(0)
# Out:
# ['Testes',
#  'Data',
#  'Hora',
#  'CpuPercent',
#  'QntCpus',
#  'CpuTimesUser',
#  'CpuTimesSystem',
#  'CpuTimesIdle',
#  'MemTotal',
#  'MemAvaliable',
#  'MemUsed',
#  'DiskUsed',
#  'DiskTotal',
#  'DiskPercent',
#  'BytesSend',
#  'BytesRecv']

# %%
print(lines)
# Out:
# [['1', '2023/03/29', '02:41:15', '7.66', '4', '0.02', '2.27', '88.59', '3801', '658', '1784', '72690352', '31837', '479592104', '98304', '0', '0'], ['2', '2023/03/29', '02:41:19', '7.66', '4', '0.02', '2.27', '88.59', '3801', '653', '1784', '72690356', '31837', '479592104', '98304', '0', '0'], ['3', '2023/03/29', '02:41:22', '7.66', '4', '0.02', '2.27', '88.59', '3801', '647', '1782', '72690356', '31837', '479592104', '98304', '0', '0'], ['4', '2023/03/29', '02:41:25', '7.67', '4', '0.02', '2.27', '88.58', '3801', '642', '1789', '72690360', '31837', '479592104', '98304', '0', '0'], ['5', '2023/03/29', '02:41:28', '7.68', '4', '0.02', '2.27', '88.57', '3801', '649', '1787', '72690360', '31837', '479592104', '98304', '0', '0'], ['6', '2023/03/29', '02:41:32', '7.70', '4', '0.02', '2.27', '88.55', '3801', '643', '1793', '72690360', '31837', '479592104', '98304', '0', '0'], ['7', '2023/03/29', '02:41:35', '7.72', '4', '0.02', '2.27', '88.54', '3801', '643', '1793', '72690360', '31837', '
# ...

# %%
y = []
for k in lines:
    date = k[1] + ' ' + k[2]
    date = datetime.strptime(date, '%Y/%m/%d %H:%M:%S')
    hora = date.time()
    # CpuPercent
    CpuPercent = int(round(float(k[3])))
    # if CpuPercent not in y:
    y.append(CpuPercent)

# %%
x = []
cont = 0
for k in range(len(y)):
    cont += 3
    x.append(cont)

# %%
plt.title("CPU CONSUMIDA X SEGUNDOS (COM TESTE CARGA DE CPU BASH)")
plt.xlabel('SEGUNDOS')
plt.ylabel('CPU CONSUMIDA %')
# plt.plot(x, y, marker = 'o', c = 'g')
plt.plot(x, y, c = 'g')
# plt.ylim(50, 75)
plt.show()

# %%
y2 = []
for k in lines:
    date = k[1] + ' ' + k[2]
    date = datetime.strptime(date, '%Y/%m/%d %H:%M:%S')
    hora = date.time()
    # (MemUsed*100) / MemTotal
    memUsedPercent = (float(k[10]) * 100) / float(k[8])
    memUsedPercent = float(f'{memUsedPercent:.2f}')
    # if memUsedPercent not in y2:
    y2.append(memUsedPercent)

# %%
x2 = []
cont = 0
for k in range(len(y2)):
    cont += 3
    x2.append(cont)

# %%
print(x2)
print(y2)
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300]
# ...

# %%
plt.title("MEM CONSUMIDA X SEGUNDOS (COM TESTE CARGA DE MEM BASH)")
plt.xlabel('SEGUNDOS')
plt.ylabel('MEM CONSUMIDA %')
# plt.plot(x2, y2, linewidth=1, marker = 'o', c = 'purple')
plt.plot(x2, y2, linewidth=1, c = 'purple')
plt.show()
