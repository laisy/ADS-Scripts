# %%
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import time

# %%
# names_columns = ["Testes", "DataHora", "CpuPercent", "QntCpus", "CpuTimesUser", "CpuTimesSystem", "CpuTimesIdle", "MemTotal", "MemAvaliable", "MemUsed", "DiskUsed", "DiskTotal", "DiskPercent", "BytesSend", "BytesRecv"]
# df = pd.read_csv("monitoramento.txt", names=names_columns)

# %%
lines = []
for line in open('/home/laisy/Documentos/ADS/ADS-Scripts/Scripts_Bash/monitoramento_bash.txt', 'r'):
    lines.append(line.split())

# %%
print(lines)
# Out:
# [['Testes', 'Data', 'Hora', 'CpuPercent', 'QntCpus', 'CpuTimesUser', 'CpuTimesSystem', 'CpuTimesIdle', 'MemTotal', 'MemAvaliable', 'MemUsed', 'DiskUsed', 'DiskTotal', 'DiskPercent', 'BytesSend', 'BytesRecv'], ['1', '2023/03/29', '02:20:55', '6.84', '4', '0.02', '2.31', '89.29', '3801', '832', '1664', '72689360', '31837', '479592104', '98304', '0', '0'], ['2', '2023/03/29', '02:20:58', '6.84', '4', '0.02', '2.31', '89.29', '3801', '830', '1662', '72689360', '31837', '479592104', '98304', '0', '0'], ['3', '2023/03/29', '02:21:01', '6.84', '4', '0.02', '2.31', '89.29', '3801', '830', '1664', '72689360', '31837', '479592104', '98304', '0', '0'], ['4', '2023/03/29', '02:21:04', '6.84', '4', '0.02', '2.31', '89.29', '3801', '841', '1653', '72689360', '31837', '479592104', '98304', '0', '0'], ['5', '2023/03/29', '02:21:07', '6.84', '4', '0.02', '2.31', '89.29', '3801', '840', '1654', '72689360', '31837', '479592104', '98304', '0', '0'], ['6', '2023/03/29', '02:21:10', '6.84', '4', '0.02', '2.31', '89.29', '3801', '838', '1655', '72689360', '31837', '479592104', '98304', '0', '0'], ['7', '2023/03/29', '02:21:13', '6.84', '4', '0.02', '2.31', '89.29', '3801', '835', '1658', '72689376', '31837', '479592104', '98304', '0', '0'], ['8', '2023/03/29', '02:21:17', '6.84', '4', '0.02', '2.31', '89.29', '3801', '828', '1654', '72689376', '31837', '479592104', '98304', '0', '0'], ['9', '2023/03/29', '02:21:20', '6.84', '4', '0.02', '2.31', '89.30', '3801', '830', '1660', '72689376', '31837', '479592104', '98304', '0', '0'], ['10', '2023/03/29', '02:21:23', '6.84', '4', '0.02', '2.31', '89.30', '3801', '828', '1662', '72689376', '31837', '479592104', '98304', '0', '0'], ['11', '2023/03/29', '02:21:26', '6.83', '4', '0.02', '2.31', '89.30', '3801', '825', '1665', '72689376', '31837', '479592104', '98304', '0', '0'], ['12', '2023/03/29', '02:21:29', '6.83', '4', '0.02', '2.31', '89.30', '3801', '832', '1657', '72689376', '31837', '479592104', '98304', '0', '0'], ['13', '2023/03/29', '02:21:32', '6.83', '4', '0.02', '2.31', '89.30', '3801', '831', '1657', '72689620', '31837', '479592104', '98304', '0', '0'], ['14', '2023/03/29', '02:21:35', '6.83', '4', '0.02', '2.31', '89.30', '3801', '830', '1660', '72689620', '31837', '479592104', '98304', '0', '0'], ['15', '2023/03/29', '02:21:38', '6.83', '4', '0.02', '2.31', '89.30', '3801', '828', '1662', '72689620', '31837', '479592104', '98304', '0', '0'], ['16', '2023/03/29', '02:21:41', '6.83', '4', '0.02', '2.31', '89.30', '3801', '834', '1655', '72689608', '31837', '479592104', '98304', '0', '0'], ['17', '2023/03/29', '02:21:44', '6.83', '4', '0.02', '2.31', '89.30', '3801', '830', '1660', '72689608', '31837', '479592104', '98304', '0', '0'], ['18', '2023/03/29', '02:21:47', '6.83', '4', '0.02', '2.31', '89.31', '3801', '830', '1659', '72689608', '31837', '479592104', '98304', '0', '0'], ['19', '2023/03/29', '02:21:51', '6.83', '4', '0.02', '2.31', '89.31', '3801', '835', '1655', '72689608', '31837', '479592104', '98304', '0', '0'], ['20', '2023/03/29', '02:21:54', '6.83', '4', '0.02', '2.31', '89.31', '3801', '840', '1650', '72689608', '31837', '479592104', '98304', '0', '0'], ['21', '2023/03/29', '02:21:57', '6.83', '4', '0.02', '2.31', '89.31', '3801', '844', '1645', '72689608', '31837', '479592104', '98304', '0', '0'], ['22', '2023/03/29', '02:22:00', '6.83', '4', '0.02', '2.31', '89.31', '3801', '842', '1648', '72689608', '31837', '479592104', '98304', '0', '0'], ['23', '2023/03/29', '02:22:03', '6.83', '4', '0.02', '2.31', '89.31', '3801', '839', '1650', '72689608', '31837', '479592104', '98304', '0', '0'], ['24', '2023/03/29', '02:22:06', '6.82', '4', '0.02', '2.31', '89.31', '3801', '838', '1653', '72689608', '31837', '479592104', '98304', '0', '0'], ['25', '2023/03/29', '02:22:09', '6.82', '4', '0.02', '2.31', '89.31', '3801', '836', '1655', '72689612', '31837', '479592104', '98304', '0', '0'], ['26', '2023/03/29', '02:22:12', '6.82', '4', '0.02', '2.31', '89.31', '3801', '843', '1650', '72689 ...

# %%
lines.pop(0)
# Out:
# ['Testes',
#  'Data',
#  'Hora',
#  'CpuPercent',
#  'QntCpus',
#  'CpuTimesUser',
#  'CpuTimesSystem',
#  'CpuTimesIdle',
#  'MemTotal',
#  'MemAvaliable',
#  'MemUsed',
#  'DiskUsed',
#  'DiskTotal',
#  'DiskPercent',
#  'BytesSend',
#  'BytesRecv']

# %%
print(lines)
# Out:
# [['1', '2023/03/29', '02:20:55', '6.84', '4', '0.02', '2.31', '89.29', '3801', '832', '1664', '72689360', '31837', '479592104', '98304', '0', '0'], ['2', '2023/03/29', '02:20:58', '6.84', '4', '0.02', '2.31', '89.29', '3801', '830', '1662', '72689360', '31837', '479592104', '98304', '0', '0'], ['3', '2023/03/29', '02:21:01', '6.84', '4', '0.02', '2.31', '89.29', '3801', '830', '1664', '72689360', '31837', '479592104', '98304', '0', '0'], ['4', '2023/03/29', '02:21:04', '6.84', '4', '0.02', '2.31', '89.29', '3801', '841', '1653', '72689360', '31837', '479592104', '98304', '0', '0'], ['5', '2023/03/29', '02:21:07', '6.84', '4', '0.02', '2.31', '89.29', '3801', '840', '1654', '72689360', '31837', '479592104', '98304', '0', '0'], ['6', '2023/03/29', '02:21:10', '6.84', '4', '0.02', '2.31', '89.29', '3801', '838', '1655', '72689360', '31837', '479592104', '98304
# %%
y = []
for k in lines:
    date = k[1] + ' ' + k[2]
    date = datetime.strptime(date, '%Y/%m/%d %H:%M:%S')
    hora = date.time()
    # CpuPercent
    CpuPercent = int(round(float(k[3])))
    # if CpuPercent not in y:
    y.append(CpuPercent)

# %%
x = []
cont = 0
for k in range(len(y)):
    cont += 3
    x.append(cont)

# %%
plt.title("CPU CONSUMIDA X SEGUNDOS (COM TESTE CARGA DE CPU BASH)")
plt.xlabel('SEGUNDOS')
plt.ylabel('CPU CONSUMIDA %')
# plt.plot(x, y, marker = 'o', c = 'g')
plt.plot(x, y, c = 'g')
# plt.ylim(50, 75)
plt.show()

# %%
y2 = []
for k in lines:
    date = k[1] + ' ' + k[2]
    date = datetime.strptime(date, '%Y/%m/%d %H:%M:%S')
    hora = date.time()
    # (MemUsed*100) / MemTotal
    memUsedPercent = (float(k[10]) * 100) / float(k[8])
    memUsedPercent = float(f'{memUsedPercent:.2f}')
    # if memUsedPercent not in y2:
    y2.append(memUsedPercent)

# %%
x2 = []
cont = 0
for k in range(len(y2)):
    cont += 3
    x2.append(cont)

# %%
print(x2)
print(y2)
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300]
# [43.78, 43.73, 43.78, 43.49, 43.51, 43.54, 43.62, 43.51, 43.67, 43.73, 43.8, 43.59, 43.59, 43.67, 43.73, 43.54, 43.67, 43.65, 43.54, 43.41, 43.28, 43.36, 43.41, 43.49, 43.54, 43.41, 43.46, 43.49, 43.51, 43.62, 43.62, 43.65, 43.65, 43.38, 43.51, 43.36, 43.2, 43.23, 43.33, 43.46, 43.57, 43.57, 43.44, 43.49, 43.51, 43.59, 43.41, 43.46, 43.49, 43.54, 43.54, 43.54, 43.59, 43.54, 43.54, 43.46, 43.51, 43.12, 43.2, 43.28, 43.46, 43.09, 43.17, 43.23, 43.25, 43.28, 43.38, 43.23, 43.23, 43.25, 43.33, 43.36, 43.36, 43.46, 43.51, 43.51, 43.33, 43.41, 43.41, 43.51, 43.54, 43.41, 43.41, 43.49, 43.36, 43.46, 43.51, 43.49, 43.54, 43.33, 43.41, 43.46, 43.49, 43.54, 43.57, 43.59, 43.54, 43.54, 43.59, 43.59]

# %%
plt.title("MEM CONSUMIDA X SEGUNDOS (COM TESTE CARGA DE MEM BASH)")
plt.xlabel('SEGUNDOS')
plt.ylabel('MEM CONSUMIDA %')
# plt.plot(x2, y2, linewidth=1, marker = 'o', c = 'purple')
plt.plot(x2, y2, linewidth=1, c = 'purple')
plt.show()
