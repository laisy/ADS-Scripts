# %%
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import time

# %%
# names_columns = ["Testes", "DataHora", "CpuPercent", "QntCpus", "CpuTimesUser", "CpuTimesSystem", "CpuTimesIdle", "MemTotal", "MemAvaliable", "MemUsed", "DiskUsed", "DiskTotal", "DiskPercent", "BytesSend", "BytesRecv"]
# df = pd.read_csv("monitoramento.txt", names=names_columns)

# %%
lines = []
for line in open('/home/laisy/Documentos/ADS/ADS-Scripts/resultado_processo_java_memoria.txt', 'r'):
    lines.append(line.split())

# %%
print(lines)
# Out:
# [['DATA_ATUAL', 'HORA_ATUAL', 'PID', 'MEMTOTAL', '%CPU', '%MEM', 'TIME', 'MSECOND'], ['2023-03-28', '02:24:19', '48688', '3892952', '154', '2.8', '00:00:04', '554404000'], ['2023-03-28', '02:24:20', '48688', '3892952', '116', '2.8', '00:00:04', '417604000'], ['2023-03-28', '02:24:21', '48688', '3892952', '93.0', '2.8', '00:00:04', '334804000'], ['2023-03-28', '02:24:22', '48688', '3892952', '77.8', '2.7', '00:00:04', '280084000'], ['2023-03-28', '02:24:23', '48688', '3892952', '66.7', '2.7', '00:00:04', '240124000'], ['2023-03-28', '02:24:24', '48688', '3892952', '58.3', '2.7', '00:00:04', '209884000'], ['2023-03-28', '02:24:25', '48688', '3892952', '52.0', '2.7', '00:00:04', '187204000'], ['2023-03-28', '02:24:26', '48688', '3892952', '46.8', '2.6', '00:00:04', '168484000'], ['2023-03-28', '02:24:27', '48688', '3892952', '42.6', '2.6', '00:00:04', '153364000'], ['2023-03-28', '02:24:29', '48688', '3892952', '39.0', '2.6', '00:00:04', '140404000'], ['2023-03-28', '02:24:30', '48688', '3892952', '36.1', '2.6', '00:00:04', '129964000'], ['2023-03-28', '02:24:31', '48688', '3892952', '33.5', '2.6', '00:00:04', '120604000'], ['2023-03-28', '02:24:32', '48688', '3892952', '31.3', '2.6', '00:00:04', '112684000'], ['2023-03-28', '02:24:33', '48688', '3892952', '29.4', '2.6', '00:00:04', '105844000'], ['2023-03-28', '02:24:34', '48688', '3892952', '27.7', '2.6', '00:00:04', '99724000'], ['2023-03-28', '02:24:35', '48688', '3892952', '26.1', '2.6', '00:00:04', '93964000'], ['2023-03-28', '02:24:36', '48688', '3892952', '24.8', '2.6', '00:00:04', '89284000'], ['2023-03-28', '02:24:37', '48688', '3892952', '22.4', '2.6', '00:00:04', '80644000'], ['2023-03-28', '02:24:38', '48688', '3892952', '21.4', '2.6', '00:00:04', '77044000'], ['2023-03-28', '02:24:39', '48688', '3892952', '20.5', '2.6', '00:00:04', '73804000'], ['2023-03-28', '02:24:41', '48688', '3892952', '19.7', '2.6', '00:00:04', '70924000'], ['2023-03-28', '02:24:42', '48688', '3892952', '18.9', '2.6', '00:00:04', '68044000'], ['2023-03-28', '02:24:43', '48688', '3892952', '17.5', '2.6', '00:00:04', '63004000'], ['2023-03-28', '02:24:44', '48688', '3892952', '16.9', '2.6', '00:00:04', '6.0844e+07'], ['2023-03-28', '02:24:45', '48688', '3892952', '16.3', '2.6', '00:00:04', '58684000'], ['2023-03-28', '02:24:47', '48688', '3892952', '15.8', '2.6', '00:00:04', '56884000'], ['2023-03-28', '02:24:48', '48688', '3892952', '15.3', '2.6', '00:00:04', '55084000'], ['2023-03-28', '02:24:49', '48688', '3892952', '14.4', '2.6', '00:00:04', '51844000'], ['2023-03-28', '02:24:50', '48688', '3892952', '14.0', '2.6', '00:00:04', '50404000'], ['2023-03-28', '02:24:51', '48688', '3892952', '13.6', '2.6', '00:00:04', '48964000'], ['2023-03-28', '02:24:53', '48688', '3892952', '13.2', '2.6', '00:00:04', '47524000'], ['2023-03-28', '02:24:54', '48688', '3892952', '12.9', '2.6', '00:00:04', '46444000'], ['2023-03-28', '02:24:55', '48688', '3892952', '12.5', '2.6', '00:00:04', '45004000'], ['2023-03-28', '02:24:56', '48688', '3892952', '11.9', '2.6', '00:00:04', '42844000'], ['2023-03-28', '02:24:57', '48688', '3892952', '11.6', '2.6', '00:00:04', '41764000'], ['2023-03-28', '02:24:59', '48688', '3892952', '11.4', '2.6', '00:00:04', '41044000'], ['2023-03-28', '02:25:00', '48688', '3892952', '11.1', '2.6', '00:00:04', '39964000'], ['2023-03-28', '02:25:01', '48688', '3892952', '10.7', '2.6', '00:00:04', '38524000'], ['2023-03-28', '02:25:02', '48688', '3892952', '10.5', '2.6', '00:00:04', '37804000'], ['2023-03-28', '02:25:03', '48688', '3892952', '10.3', '2.6', '00:00:04', '37084000'], ['2023-03-28', '02:25:05', '48688', '3892952', '10.1', '2.6', '00:00:04', '36364000'], ['2023-03-28', '02:25:06', '48688', '3892952', '9.9', '2.6', '00:00:04', '35644000'], ['2023-03-28', '02:25:07', '48688', '3892952', '9.5', '2.6', '00:00:04', '34204000'], ['2023-03-28', '02:25:08', '48688', '3892952', '9.4', '2.6', '00:00:04', '33844000'], ['2023-03-28', '02:25:09', '48688', '3892952', '9.3', '2.6', '00:00:04', '33 ...

# %%
lines.pop(0)
# Out:
# ['DATA_ATUAL',
#  'HORA_ATUAL',
#  'PID',
#  'MEMTOTAL',
#  '%CPU',
#  '%MEM',
#  'TIME',
#  'MSECOND']

# %%
tempos = []
for k in lines:
    date = k[0] + ' ' + k[1]
    date = datetime.strptime(date, '%Y-%m-%d %H:%M:%S')
    hora = date.time()

    tempos.append(date)
 
tempo_processo = tempos[-1] - tempos[0]
print('TEMPO PROCESSO JAVA COM CARGA:', tempo_processo)
# Out:
# TEMPO PROCESSO JAVA COM CARGA: 0:05:49

# %%
cpus = []
for k in lines:
    cpus.append(float(k[4]))
 
cpus_utilizada =  "{:.2f}".format(sum(cpus) / len(cpus))
print('%CPU PROCESSO JAVA COM CARGA:', cpus_utilizada, "%")
# Out:
# %CPU PROCESSO JAVA COM CARGA: 7.05 %

# %%
memorias = []
for k in lines:
    memorias.append(float(k[5]))
 
memorias_utilizada =  "{:.2f}".format(sum(memorias) / len(memorias))
print('%MEM PROCESSO JAVA COM CARGA:', memorias_utilizada, "%")
# Out:
# %MEM PROCESSO JAVA COM CARGA: 2.74 %

# %%
memorias = []
for k in lines:

    # MEMTOTAL bytes
    mem_value = (float(k[5])*int(k[3]))/100
    memorias.append(mem_value)
 
memorias_utilizada = sum(memorias) / len(memorias)
memorias_utilizada = "{:.2f}".format(memorias_utilizada/1024)

print('MEM PROCESSO JAVA COM CARGA:', memorias_utilizada, 'KB')
# Out:
# MEM PROCESSO JAVA COM CARGA: 104.10 KB
