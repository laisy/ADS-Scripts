# %%
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import time

# %%
# names_columns = ["Testes", "DataHora", "CpuPercent", "QntCpus", "CpuTimesUser", "CpuTimesSystem", "CpuTimesIdle", "MemTotal", "MemAvaliable", "MemUsed", "DiskUsed", "DiskTotal", "DiskPercent", "BytesSend", "BytesRecv"]
# df = pd.read_csv("monitoramento.txt", names=names_columns)

# %%
lines = []
for line in open('/home/laisy/Documentos/ADS/ADS-Scripts/Scripts-Python/monitoramento_py.txt', 'r'):
    lines.append(line.split())

# %%
print(lines)
# Out:
# [['Testes', 'Data', 'Hora', 'CpuPercent', 'QntCpus', 'CpuTimesUser', 'CpuTimesSystem', 'CpuTimesIdle', 'MemTotal', 'MemAvaliable', 'MemUsed', 'DiskUsed', 'DiskTotal', 'DiskPercent', 'BytesSend', 'BytesRecv'], ['1', '2023/03/27', '23:03:48', '9.80', '4.00', '265.40', '238.03', '3033.14', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560271'], ['2', '2023/03/27', '23:03:51', '2.50', '4.00', '265.57', '238.25', '3044.57', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560341'], ['3', '2023/03/27', '23:03:54', '2.00', '4.00', '265.68', '238.40', '3056.26', '3.71', '2.07', '1.15', '69.27', '457.37467193603516', '16.0', '4560341'], ['4', '2023/03/27', '23:03:57', '2.30', '4.00', '265.82', '238.53', '3067.99', '3.71', '2.07', '1.15', '69.27', '457.37467193603516', '16.0', '4560341'], ['5', '2023/03/27', '23:04:00', '1.50', '4.00', '265.91', '238.63', '3079.74', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560341'], ['6', '2023/03/27', '23:04:03', '2.30', '4.00', '266.07', '238.76', '3091.42', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560411'], ['7', '2023/03/27', '23:04:06', '2.00', '4.00', '266.16', '238.90', '3103.12', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560411'], ['8', '2023/03/27', '23:04:09', '2.00', '4.00', '266.26', '239.02', '3114.84', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560529'], ['9', '2023/03/27', '23:04:12', '2.50', '4.00', '266.36', '239.16', '3126.56', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560529'], ['10', '2023/03/27', '23:04:15', '11.10', '4.00', '266.79', '239.35', '3137.88', '3.71', '2.06', '1.16', '69.27', '457.37467193603516', '16.0', '4560669'], ['11', '2023/03/27', '23:04:18', '2.30', '4.00', '266.92', '239.48', '3149.58', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560669'], ['12', '2023/03/27', '23:04:21', '2.80', '4.00', '267.05', '239.66', '3161.12', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560669'], ['13', '2023/03/27', '23:04:24', '2.50', '4.00', '267.16', '239.74', '3172.87', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560739'], ['14', '2023/03/27', '23:04:27', '4.20', '4.00', '267.44', '239.96', '3184.40', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560739'], ['15', '2023/03/27', '23:04:30', '5.20', '4.00', '267.78', '240.12', '3195.86', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560739'], ['16', '2023/03/27', '23:04:33', '2.00', '4.00', '267.89', '240.27', '3207.58', '3.71', '2.06', '1.16', '69.27', '457.37467193603516', '16.0', '4560829'], ['17', '2023/03/27', '23:04:36', '1.80', '4.00', '267.98', '240.43', '3219.28', '3.71', '2.06', '1.16', '69.27', '457.37467193603516', '16.0', '4560899'], ['18', '2023/03/27', '23:04:39', '2.00', '4.00', '268.10', '240.56', '3231.01', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560899'], ['19', '2023/03/27', '23:04:42', '1.80', '4.00', '268.20', '240.71', '3242.71', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560899'], ['20', '2023/03/27', '23:04:45', '1.00', '4.00', '268.29', '240.83', '3254.45', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560899'], ['21', '2023/03/27', '23:04:48', '2.20', '4.00', '268.37', '240.94', '3266.22', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560969'], ['22', '2023/03/27', '23:04:51', '2.50', '4.00', '268.48', '241.08', '3277.95', '3.71', '2.06', '1.16', '69.27', '457.37467193603516', '16.0', '4560969'], ['23', '2023/03/27', '23:04:54', '1.80', '4.00', '268.58', '241.20', '3289.64', '3.71', '2.06', '1.16', '69.27', '457.37467193603516', '16.0', '4561086'], ['24', '2023/03/27', '23:04:57', '2.00', '4.00', '268.67', '241.33', '3301.37', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4561156'], ['25', '2023/03/27', '23:05:00', '1.80', '4.00', '268.76', '241.48', '3313.08', ...

# %%
lines.pop(0)
# Out:
# ['Testes',
#  'Data',
#  'Hora',
#  'CpuPercent',
#  'QntCpus',
#  'CpuTimesUser',
#  'CpuTimesSystem',
#  'CpuTimesIdle',
#  'MemTotal',
#  'MemAvaliable',
#  'MemUsed',
#  'DiskUsed',
#  'DiskTotal',
#  'DiskPercent',
#  'BytesSend',
#  'BytesRecv']

# %%
print(lines)
# Out:
# [['1', '2023/03/27', '23:03:48', '9.80', '4.00', '265.40', '238.03', '3033.14', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560271'], ['2', '2023/03/27', '23:03:51', '2.50', '4.00', '265.57', '238.25', '3044.57', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560341'], ['3', '2023/03/27', '23:03:54', '2.00', '4.00', '265.68', '238.40', '3056.26', '3.71', '2.07', '1.15', '69.27', '457.37467193603516', '16.0', '4560341'], ['4', '2023/03/27', '23:03:57', '2.30', '4.00', '265.82', '238.53', '3067.99', '3.71', '2.07', '1.15', '69.27', '457.37467193603516', '16.0', '4560341'], ['5', '2023/03/27', '23:04:00', '1.50', '4.00', '265.91', '238.63', '3079.74', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560341'], ['6', '2023/03/27', '23:04:03', '2.30', '4.00', '266.07', '238.76', '3091.42', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560411'], ['7', '2023/03/27', '23:04:06', '2.00', '4.00', '266.16', '238.90', '3103.12', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560411'], ['8', '2023/03/27', '23:04:09', '2.00', '4.00', '266.26', '239.02', '3114.84', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560529'], ['9', '2023/03/27', '23:04:12', '2.50', '4.00', '266.36', '239.16', '3126.56', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560529'], ['10', '2023/03/27', '23:04:15', '11.10', '4.00', '266.79', '239.35', '3137.88', '3.71', '2.06', '1.16', '69.27', '457.37467193603516', '16.0', '4560669'], ['11', '2023/03/27', '23:04:18', '2.30', '4.00', '266.92', '239.48', '3149.58', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560669'], ['12', '2023/03/27', '23:04:21', '2.80', '4.00', '267.05', '239.66', '3161.12', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560669'], ['13', '2023/03/27', '23:04:24', '2.50', '4.00', '267.16', '239.74', '3172.87', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560739'], ['14', '2023/03/27', '23:04:27', '4.20', '4.00', '267.44', '239.96', '3184.40', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560739'], ['15', '2023/03/27', '23:04:30', '5.20', '4.00', '267.78', '240.12', '3195.86', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560739'], ['16', '2023/03/27', '23:04:33', '2.00', '4.00', '267.89', '240.27', '3207.58', '3.71', '2.06', '1.16', '69.27', '457.37467193603516', '16.0', '4560829'], ['17', '2023/03/27', '23:04:36', '1.80', '4.00', '267.98', '240.43', '3219.28', '3.71', '2.06', '1.16', '69.27', '457.37467193603516', '16.0', '4560899'], ['18', '2023/03/27', '23:04:39', '2.00', '4.00', '268.10', '240.56', '3231.01', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560899'], ['19', '2023/03/27', '23:04:42', '1.80', '4.00', '268.20', '240.71', '3242.71', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560899'], ['20', '2023/03/27', '23:04:45', '1.00', '4.00', '268.29', '240.83', '3254.45', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560899'], ['21', '2023/03/27', '23:04:48', '2.20', '4.00', '268.37', '240.94', '3266.22', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4560969'], ['22', '2023/03/27', '23:04:51', '2.50', '4.00', '268.48', '241.08', '3277.95', '3.71', '2.06', '1.16', '69.27', '457.37467193603516', '16.0', '4560969'], ['23', '2023/03/27', '23:04:54', '1.80', '4.00', '268.58', '241.20', '3289.64', '3.71', '2.06', '1.16', '69.27', '457.37467193603516', '16.0', '4561086'], ['24', '2023/03/27', '23:04:57', '2.00', '4.00', '268.67', '241.33', '3301.37', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4561156'], ['25', '2023/03/27', '23:05:00', '1.80', '4.00', '268.76', '241.48', '3313.08', '3.71', '2.07', '1.16', '69.27', '457.37467193603516', '16.0', '4561156'], ['26', '2023/03/27', '23:05:03', '2.50', '4.00', '268.86', '241.66', '3324.75', '3.71', '2.07', '1.16', '69.27', '457.37467193603516 ...

# %%
y = []
for k in lines:
    date = k[1] + ' ' + k[2]
    date = datetime.strptime(date, '%Y/%m/%d %H:%M:%S')
    hora = date.time()
    # CpuPercent
    CpuPercent = int(round(float(k[3])))
    # if CpuPercent not in y:
    y.append(CpuPercent)

# %%
x = []
cont = 0
for k in range(len(y)):
    cont += 3
    x.append(cont)

# %%
plt.title("CPU CONSUMIDA X SEGUNDOS (SEM TESTE CARGA DE CPU PY)")
plt.xlabel('SEGUNDOS')
plt.ylabel('CPU CONSUMIDA %')
# plt.plot(x, y, marker = 'o', c = 'g')
plt.plot(x, y, c = 'g')
# plt.ylim(50, 75)
plt.show()

# %%
y2 = []
for k in lines:
    date = k[1] + ' ' + k[2]
    date = datetime.strptime(date, '%Y/%m/%d %H:%M:%S')
    hora = date.time()
    # (MemUsed*100) / MemTotal
    memUsedPercent = (float(k[10]) * 100) / float(k[8])
    memUsedPercent = float(f'{memUsedPercent:.2f}')
    # if memUsedPercent not in y2:
    y2.append(memUsedPercent)

# %%
x2 = []
cont = 0
for k in range(len(y2)):
    cont += 3
    x2.append(cont)

# %%
print(x2)
print(y2)
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300]
# [31.27, 31.27, 31.0, 31.0, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.27, 31.54, 31.27, 31.27, 31.0, 31.0, 31.0, 29.92, 29.92, 29.92, 29.92, 29.92, 29.92, 29.92, 29.92, 30.19, 30.19, 30.19, 29.92, 29.65, 29.65, 29.65, 29.65, 29.65, 29.92, 29.92, 29.92, 29.92, 29.92, 29.92, 29.92, 29.92, 29.92, 29.92, 29.92, 29.92, 29.92, 29.92, 29.92, 30.19, 30.19, 30.19, 30.19, 30.19, 29.92, 29.65, 29.92, 29.92, 29.92, 29.92, 29.92, 29.92, 29.92, 29.92]

# %%
plt.title("MEM CONSUMIDA X SEGUNDOS (SEM TESTE CARGA DE MEM PY)")
plt.xlabel('SEGUNDOS')
plt.ylabel('MEM CONSUMIDA %')
# plt.plot(x2, y2, linewidth=1, marker = 'o', c = 'purple')
plt.plot(x2, y2, linewidth=1, c = 'purple')
plt.show()
